# %% [markdown]
# # airground — PPO training on Colab
# Runtime > Change runtime type > **T4 GPU** 선택 후 실행.
# 체크포인트는 Drive에 저장 (세션 끊겨도 유지).

# %%
from google.colab import drive

drive.mount('/content/drive')
OUT = '/content/drive/MyDrive/airground_runs/ppo_v0'

# %%
# !git clone https://github.com/didvicals/airground.git
# %cd airground
# !pip install -q -e .[train]

# %%
# smoke test before burning GPU time
# !python tests/test_framework.py

# %%
# %load_ext tensorboard
# %tensorboard --logdir $OUT/tb

# %%
# !python scripts/train_ppo.py --steps 2000000 --nenv 8 --out $OUT

# %% [markdown]
# 세션 끊긴 경우 재개: `--resume $OUT/final.zip` 추가 후 재실행.
